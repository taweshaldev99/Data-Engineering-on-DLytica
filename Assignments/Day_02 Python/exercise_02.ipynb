# %% [markdown]
# ### Exercise 2: Retry Simulation

# %%
attempts = int(input("Enter attempts amount: "))
max_attempts = int(input("Enter max_attempts amount: "))
operation_successful = bool

while attempts <= max_attempts :
    print("Operation completed Successfully")
    break

while attempts >= max_attempts :
    print(f'operation failed after three attempts')
