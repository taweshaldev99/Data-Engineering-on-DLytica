# %% [markdown]
# ## Exercise 1: Batch Processor

# %%
for i in range (1,11):
        print(f"Processing Batch {i}")

        if i % 3 == 0:
                print("Checkpoint Reached")
# Out:
# Processing Batch 1
# Processing Batch 2
# Processing Batch 3
# Checkpoint Reached
# Processing Batch 4
# Processing Batch 5
# Processing Batch 6
# Checkpoint Reached
# Processing Batch 7
# Processing Batch 8
# Processing Batch 9
# Checkpoint Reached
# Processing Batch 10
