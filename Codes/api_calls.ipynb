# %%
import requests

# %%
response = requests.get("https://api.frankfurter.dev/v1/latest",params={"from":"AUD"},timeout=10)
print(response.json())
# Out:
# {'amount': 1.0, 'base': 'AUD', 'date': '2026-08-14', 'rates': {'BRL': 3.6658, 'CAD': 0.98261, 'CHF': 0.57491, 'CNY': 4.7742, 'CZK': 14.8197, 'DKK': 4.5771, 'EUR': 0.61226, 'GBP': 0.52317, 'HKD': 5.5575, 'HUF': 221.99, 'IDR': 12597, 'ILS': 2.0889, 'INR': 67.581, 'ISK': 87.06, 'JPY': 112.61, 'KRW': 999.46, 'MXN': 12.0365, 'MYR': 2.8937, 'NOK': 6.6935, 'NZD': 1.2026, 'PHP': 43.475, 'PLN': 2.6369, 'RON': 3.2099, 'SEK': 6.7342, 'SGD': 0.90516, 'THB': 23.459, 'TRY': 33.912, 'USD': 0.7082, 'ZAR': 11.4479}}
